# %% [markdown]
# <a href="https://colab.research.google.com/github/NeDarbandsari/Facial-Emotion-Detection/blob/main/Edited_Emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import display
# !pip install deepface
display.clear_output()

from deepface import DeepFace
import cv2
import os
from google.colab import drive

import pandas as pd
import json

from itertools import groupby
# Out:
# 25-10-16 11:02:48 - Directory /root/.deepface has been created
# 25-10-16 11:02:48 - Directory /root/.deepface/weights has been created

# %%
drive.mount("/content/drive", force_remount=True)

ZIP_PATH = "/content/drive/MyDrive/Recordings.zip"
ROOT_DIR = "/content/drive/MyDrive/Recordings"
OUTPUT_CSV = "/content/drive/MyDrive/emotion_results.csv"
ALLOWED_EXTS = (".mp4", ".mov", ".avi", ".mkv", ".m4v")


if not os.path.exists(ROOT_DIR):
    print("Extracting dataset, please wait...")
    import zipfile
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(ROOT_DIR)
    print("Extraction complete:", ROOT_DIR)
else:
    print("Dataset folder already exists:", ROOT_DIR)
# Out:
# Mounted at /content/drive
# Extracting dataset, please wait...
# Extraction complete: /content/drive/MyDrive/Recordings

# %%
def iter_videos(root_dir, allowed_exts=ALLOWED_EXTS):
    for dirpath, dirnames, filenames in os.walk(root_dir):
        dirnames.sort()
        for fn in sorted(filenames):
            if fn.lower().endswith(allowed_exts):
                yield dirpath, fn, os.path.join(dirpath, fn)

all_videos = list(iter_videos(ROOT_DIR))
print(f"Found {len(all_videos)} video(s). Example:", all_videos[0])
# Out:
# Found 491 video(s). Example: ('/content/drive/MyDrive/Recordings/Recordings/01', '01-01-01-01.mp4', '/content/drive/MyDrive/Recordings/Recordings/01/01-01-01-01.mp4')

# %%
def video_emotion_detection(video, backends, alignment_modes, model,video_path):
  emotion_model = DeepFace.build_model(model)
  DeepFace.custom_models = {model: emotion_model}
  print("processing ", video)

  cap = cv2.VideoCapture(os.path.join(video_path, video))

  fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
  frame_interval = int(fps)

  prev_emotion = None
  start_time = None
  frame_count = 0
  result = {}
  result['file'] = video
  result['model'] = model
  result['backends'] = backends

  emotion=[]

  while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

      # Process only every frame_interval-th frame
    if frame_count % frame_interval == 0:
        process = {}
        current_time = frame_count / fps  # current time in seconds
        try:
            # Analyze the current frame for emotion
            analysis = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False, detector_backend = backends)

            # If the result is a list (multiple faces), take the first one
            if isinstance(analysis, list):
                analysis = analysis[0]
            curr_emotion = analysis['dominant_emotion']

            # Initialize on the first processed frame
            if prev_emotion is None:
                prev_emotion = curr_emotion
                start_time = current_time
                print(f"Starting with emotion '{curr_emotion}' at {current_time:.1f}s")
                process['starting emotion'] = curr_emotion
                process['time'] = current_time
            # When the emotion changes, print the duration and update the tracker
            elif curr_emotion != prev_emotion:
                duration = current_time - start_time
                print(f"Emotion '{prev_emotion}' lasted for {duration:.1f} seconds")
                process['prev_emotion'] = prev_emotion
                process['duration'] = duration
                print(f"At {current_time:.1f}s, dominant emotion changed to '{curr_emotion}'")
                process['curr_emotion'] = curr_emotion
                process['current_time'] =current_time
                prev_emotion = curr_emotion
                start_time = current_time
            if len(process) != 0:
              emotion.append(process)
        except Exception as e:
            print(f"Error analyzing frame {frame_count}: {e}")


    frame_count += 1
  cap.release()
  # Print the duration for the final emotion
  total_time = frame_count / fps
  if prev_emotion is not None and start_time is not None:
    final_duration = total_time - start_time
    print(f"Final emotion '{prev_emotion}' lasted for {final_duration:.1f} seconds")
  print("Analysis complete.")
  result['emotions'] = emotion
  return result

# %%
backends = [
  'opencv',
  'ssd',
  'dlib',
  'mtcnn',
  'fastmtcnn',
  'retinaface',
  'mediapipe',
  'yolov8',
  'yolov11s',
  'yolov11n',
  'yolov11m',
  'yunet',
  'centerface',
]

alignment_modes = [True, False]

supported_models = [
    "VGG-Face",
    "Facenet",
    "Facenet512",
    "OpenFace",
    "DeepFace",
    "DeepID",
    "ArcFace",
    "Dlib",
    "SFace",
]

# %%
chosen_backend   = backends[3]          # mtcnn
chosen_alignment = alignment_modes[0]   # True
chosen_model     = supported_models[3]  # OpenFace


def result_to_rows(r):
    """Flatten one video result dict into per-segment CSV rows."""
    base = {
        "folder": r.get("folder"),
        "file":   r.get("file"),
        "path":   r.get("path"),
        "model":  r.get("model"),
        "backend":r.get("backends"),
    }
    rows = []
    for emo in r.get("emotions", []):
        row = base.copy()
        row.update(emo)
        rows.append(row)
    return rows

def append_rows(rows, csv_path):
    """Append rows to CSV safely."""
    if not rows:
        return 0
    df = pd.DataFrame(rows)
    header_needed = (not os.path.exists(csv_path)) or os.stat(csv_path).st_size == 0
    df.to_csv(csv_path, mode="a", header=header_needed, index=False)
    return len(df)


# 1) Load existing CSV and mark already-processed videos
if os.path.exists(OUTPUT_CSV):
    try:
        existing = pd.read_csv(OUTPUT_CSV, usecols=["path"])
        processed_paths = set(existing["path"].astype(str))
        print(f"Found {len(processed_paths)} already processed videos in CSV.")
    except Exception:
        processed_paths = set()
        print("Could not read previous CSV — starting fresh.")
else:
    processed_paths = set()
    print("No existing CSV found. Starting fresh.")


# 2) Group videos by folder and process only new ones
all_videos_sorted = sorted(all_videos, key=lambda t: (t[0], t[1]))
total_appended = 0
folders_done = 0

try:
    for folder_path, group in groupby(all_videos_sorted, key=lambda t: t[0]):
        group = list(group)
        print(f"\n=== Folder: {folder_path} ===")

        # filter only new videos
        new_files = [(p, f, fp) for (p, f, fp) in group if fp not in processed_paths]
        if not new_files:
            print("All videos in this folder already processed.")
            folders_done += 1
            continue

        folder_rows = []
        for _, file_name, file_path in new_files:
            print(">>>", file_path)
            out = video_emotion_detection(
                file_name, chosen_backend, chosen_alignment, chosen_model, folder_path + os.sep
            )
            out["folder"] = folder_path
            out["path"] = file_path
            folder_rows.extend(result_to_rows(out))
            processed_paths.add(file_path)  # mark done in memory

        added = append_rows(folder_rows, OUTPUT_CSV)
        total_appended += added

        print(f"Saved {added} new rows from folder: {folder_path}")
        folders_done += 1

        try:
            peek = pd.read_csv(OUTPUT_CSV).tail(3)
            display(peek)
        except Exception:
            pass

except KeyboardInterrupt:
    print("\nStopped manually — progress saved so far.")

finally:
    if os.path.exists(OUTPUT_CSV):
        total_rows = pd.read_csv(OUTPUT_CSV).shape[0]
        print(f"\nResume-ready CSV updated: {OUTPUT_CSV}")
        print(f"Total processed folders: {folders_done} | New rows added: {total_appended} | Total rows in CSV: {total_rows}")
    else:
        print("\nNo CSV file was written yet.")
# Out:
# Found 20 already processed videos in CSV.
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/01 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/02 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/03 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/03/01-01-03-02.mp4
# processing  01-01-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 4.0 seconds
# At 4.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/01-02-03-02.mp4
# processing  01-02-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/02-01-03-02.mp4
# processing  02-01-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/02-02-03-02.mp4
# processing  02-02-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/03-01-03-02.mp4
# processing  03-01-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 2.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/03-02-03-02.mp4
# processing  03-02-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'surprise'
# Emotion 'surprise' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/04-01-03-02.mp4
# processing  04-01-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 1.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/04-02-03-02.mp4
# processing  04-02-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/05-01-03-02.mp4
# processing  05-01-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/03/05-02-03-02.mp4
# processing  05-02-03-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.1 seconds
# Analysis complete.
# Saved 23 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/03
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/04 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/04/01-01-04-01.mp4
# processing  01-01-04-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/01-02-04-01.mp4
# processing  01-02-04-01.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/02-01-04-01.mp4
# processing  02-01-04-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 2.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/02-02-04-01.mp4
# processing  02-02-04-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 3.0 seconds
# At 4.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 5.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/03-01-04-01.mp4
# processing  03-01-04-01.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 2.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/03-02-04-01.mp4
# processing  03-02-04-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/04-01-04-01.mp4
# processing  04-01-04-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'surprise'
# Final emotion 'surprise' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/04-02-04-01.mp4
# processing  04-02-04-01.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/05-01-04-01.mp4
# processing  05-01-04-01.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/04/05-02-04-01.mp4
# processing  05-02-04-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.3 seconds
# Analysis complete.
# Saved 27 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/04
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/05 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/05/01-01-05-02.mp4
# processing  01-01-05-02.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/01-02-05-02.mp4
# processing  01-02-05-02.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 1.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/02-01-05-02.mp4
# processing  02-01-05-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 1.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/02-02-05-02.mp4
# processing  02-02-05-02.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 2.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/03-01-05-02.mp4
# processing  03-01-05-02.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 4.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/03-02-05-02.mp4
# processing  03-02-05-02.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/04-01-05-02.mp4
# processing  04-01-05-02.mp4
# Starting with emotion 'fear' at 0.0s
# Final emotion 'fear' lasted for 3.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/04-02-05-02.mp4
# processing  04-02-05-02.mp4
# Starting with emotion 'fear' at 0.0s
# Final emotion 'fear' lasted for 5.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/05-01-05-02.mp4
# processing  05-01-05-02.mp4
# Starting with emotion 'fear' at 0.0s
# Final emotion 'fear' lasted for 3.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/05/05-02-05-02.mp4
# processing  05-02-05-02.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.8 seconds
# Analysis complete.
# Saved 21 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/05
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/06 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/06/01-01-0-06-03.mp4
# processing  01-01-0-06-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/01-02-06-03.mp4
# processing  01-02-06-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/02-01-06-03.mp4
# processing  02-01-06-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/02-02-06-03.mp4
# processing  02-02-06-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/03-01-06-03.mp4
# processing  03-01-06-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/03-02-06-03.mp4
# processing  03-02-06-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/04-01-06-03.mp4
# processing  04-01-06-03.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 2.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/04-02-06-03.mp4
# processing  04-02-06-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/05-01-06-03.mp4
# processing  05-01-06-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 2.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/06/05-02-06-03.mp4
# processing  05-02-06-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.2 seconds
# Analysis complete.
# Saved 24 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/06
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/07 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/07/01-01-07-03.mp4
# processing  01-01-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Final emotion 'happy' lasted for 1.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/01-02-07-03.mp4
# processing  01-02-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/02-01-07-03.mp4
# processing  02-01-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/02-02-07-03.mp4
# processing  02-02-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/03-01-07-03.mp4
# processing  03-01-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 0.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/03-02-07-03.mp4
# processing  03-02-07-03.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/04-01-07-03.mp4
# processing  04-01-07-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/04-02-07-03.mp4
# processing  04-02-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/05-01-07-03.mp4
# processing  05-01-07-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/07/05-02-07-03.mp4
# processing  05-02-07-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.6 seconds
# Analysis complete.
# Saved 26 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/07
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/08 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/08/01-01-08-01.mp4
# processing  01-01-08-01.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/01-02-08-01.mp4
# processing  01-02-08-01.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'happy'
# Final emotion 'happy' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/02-01-08-01.mp4
# processing  02-01-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/02-02-08-01.mp4
# processing  02-02-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/03-01-08-01.mp4
# processing  03-01-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/03-02-08-01.mp4
# processing  03-02-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/04-01-08-01.mp4
# processing  04-01-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'surprise'
# Emotion 'surprise' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 2.0 seconds
# At 4.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/04-02-08-01.mp4
# processing  04-02-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/05-01-08-01.mp4
# processing  05-01-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/08/05-02-08-01.mp4
# processing  05-02-08-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.6 seconds
# Analysis complete.
# Saved 25 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/08
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/09 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/09/01-01-09-03.mp4
# processing  01-01-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/01-02-09-03.mp4
# processing  01-02-09-03.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/02-01-09-03.mp4
# processing  02-01-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/02-02-09-03.mp4
# processing  02-02-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/03-01-09-03.mp4
# processing  03-01-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 4.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/03-02-09-03.mp4
# processing  03-02-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 4.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/04-01-09-03.mp4
# processing  04-01-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/04-02-09-03.mp4
# processing  04-02-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/05-01-09-03.mp4
# processing  05-01-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/09/05-02-09-03.mp4
# processing  05-02-09-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 4.2 seconds
# Analysis complete.
# Saved 21 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/09
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/10 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/10/01-01-10-03.mp4
# processing  01-01-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 1.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/01-02-10-03.mp4
# processing  01-02-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/02-01-10-03.mp4
# processing  02-01-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 4.0 seconds
# At 4.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/02-02-10-03.mp4
# processing  02-02-10-03.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/03-01-10-03.mp4
# processing  03-01-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 4.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/03-02-10-03.mp4
# processing  03-02-10-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/04-01-10-03.mp4
# processing  04-01-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/04-02-10-03.mp4
# processing  04-02-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 5.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/05-01-10-03.mp4
# processing  05-01-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/10/05-02-10-03.mp4
# processing  05-02-10-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.8 seconds
# Analysis complete.
# Saved 24 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/10
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/11 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/11/01-01-11-03.mp4
# processing  01-01-11-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/01-02-11-03.mp4
# processing  01-02-11-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/02-01-11-03.mp4
# processing  02-01-11-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/02-02-11-03.mp4
# processing  02-02-11-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/03-01-11-03.mp4
# processing  03-01-11-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/03-02-11-03.mp4
# processing  03-02-11-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/04-01-11-03.mp4
# processing  04-01-11-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/04-02-11-03.mp4
# processing  04-02-11-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/05-01-11-03.mp4
# processing  05-01-11-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/11/05-02-11-03.mp4
# processing  05-02-11-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.0 seconds
# Analysis complete.
# Saved 19 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/11
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/12 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/12/01-01-12-03.mp4
# processing  01-01-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/01-02-12-03.mp4
# processing  01-02-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/02-01-12-03.mp4
# processing  02-01-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/02-02-12-03.mp4
# processing  02-02-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/03-01-12-03.mp4
# processing  03-01-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/03-02-12-03.mp4
# processing  03-02-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/04-01-12-03.mp4
# processing  04-01-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/04-02-12-03.mp4
# processing  04-02-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/05-01-12-03.mp4
# processing  05-01-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'surprise'
# Final emotion 'surprise' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/12/05-02-12-03.mp4
# processing  05-02-12-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.1 seconds
# Analysis complete.
# Saved 20 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/12
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/13 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/13/01-01-13-03.mp4
# processing  01-01-13-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/01-02-13-03.mp4
# processing  01-02-13-03.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/02-01-13-03.mp4
# processing  02-01-13-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 3.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/02-02-13-03.mp4
# processing  02-02-13-03.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 4.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/03-01-13-03.mp4
# processing  03-01-13-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 2.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/03-02-13-03.mp4
# processing  03-02-13-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/04-01-13-03.mp4
# processing  04-01-13-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 2.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/04-02-13-03.mp4
# processing  04-02-13-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 5.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/05-01-13-03.mp4
# processing  05-01-13-03.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/13/05-02-13-03.mp4
# processing  05-02-13-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 3.2 seconds
# Analysis complete.
# Saved 27 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/13
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/14 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/14/01-01-14-03.mp4
# processing  01-01-14-03.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/01-02-14-03.mp4
# processing  01-02-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 2.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 3.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/02-01-14-03.mp4
# processing  02-01-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 4.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/02-02-14-03.mp4
# processing  02-02-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 5.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/03-01-14-03.mp4
# processing  03-01-14-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 6.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/03-02-14-03.mp4
# processing  03-02-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 3.0 seconds
# At 5.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/04-01-14-03.mp4
# processing  04-01-14-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 4.0 seconds
# At 5.0s, dominant emotion changed to 'surprise'
# Emotion 'surprise' lasted for 1.0 seconds
# At 6.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/04-02-14-03.mp4
# processing  04-02-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/05-01-14-03.mp4
# processing  05-01-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 7.0 seconds
# At 7.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 8.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/14/05-02-14-03.mp4
# processing  05-02-14-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 5.0 seconds
# At 5.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 6.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.1 seconds
# Analysis complete.
# Saved 31 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/14
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/15 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/15/01-01-15-03.mp4
# processing  01-01-15-03.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 2.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/01-02-15-03.mp4
# processing  01-02-15-03.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 2.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/02-01-15-03.mp4
# processing  02-01-15-03.mp4
# Starting with emotion 'happy' at 0.0s
# Final emotion 'happy' lasted for 2.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/02-02-15-03.mp4
# processing  02-02-15-03.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/03-01-15-03.mp4
# processing  03-01-15-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/03-02-15-03.mp4
# processing  03-02-15-03.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'happy'
# Final emotion 'happy' lasted for 0.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/04-01-15-03.mp4
# processing  04-01-15-03.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/04-02-15-03.mp4
# processing  04-02-15-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'happy'
# Final emotion 'happy' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/05-01-15-03.mp4
# processing  05-01-15-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/05-02-15-03.mp4
# processing  05-02-15-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/15/Video Project 14.mp4
# processing  Video Project 14.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 3.0 seconds
# At 6.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 3.0 seconds
# At 9.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 3.0 seconds
# At 12.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 5.0 seconds
# At 17.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 4.0 seconds
# At 21.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 5.0 seconds
# At 26.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 2.0 seconds
# At 28.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 29.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 2.0 seconds
# At 31.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 6.0 seconds
# At 37.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 4.0 seconds
# At 41.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 42.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 10.0 seconds
# At 52.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 2.0 seconds
# At 54.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 56.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 4.0 seconds
# At 60.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 5.0 seconds
# At 65.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 2.0 seconds
# At 67.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.7 seconds
# Analysis complete.
# Saved 46 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/15
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/16 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/16/01-01-16-03.mp4
# processing  01-01-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/01-02-16-03.mp4
# processing  01-02-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/02-01-16-03.mp4
# processing  02-01-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 1.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/02-02-16-03.mp4
# processing  02-02-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/03-01-16-03.mp4
# processing  03-01-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/03-02-16-03.mp4
# processing  03-02-16-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 1.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/04-01-16-03.mp4
# processing  04-01-16-03.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/04-02-16-03.mp4
# processing  04-02-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/05-01-16-03.mp4
# processing  05-01-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/16/05-02-16-03.mp4
# processing  05-02-16-03.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.1 seconds
# ...
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/01-02-45-04.mp4
# processing  01-02-45-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'surprise'
# Final emotion 'surprise' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/02-01-45-04.mp4
# processing  02-01-45-04.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/02-02-45-04.mp4
# processing  02-02-45-04.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/03-01-45-04.mp4
# processing  03-01-45-04.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/03-02-45-04.mp4
# processing  03-02-45-04.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 2.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/04-01-45-04.mp4
# processing  04-01-45-04.mp4
# Starting with emotion 'fear' at 0.0s
# Emotion 'fear' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/04-02-45-04.mp4
# processing  04-02-45-04.mp4
# Starting with emotion 'surprise' at 0.0s
# Emotion 'surprise' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/05-01-45-04.mp4
# processing  05-01-45-04.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 4.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/45/05-02-45-04.mp4
# processing  05-02-45-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 2.0 seconds
# Analysis complete.
# Saved 20 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/45
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/46 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/46/01-01-46-01.mp4
# processing  01-01-46-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'disgust'
# Final emotion 'disgust' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/01-02-46-01.mp4
# processing  01-02-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/02-01-46-01.mp4
# processing  02-01-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'disgust'
# Emotion 'disgust' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/02-02-46-01.mp4
# processing  02-02-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'disgust'
# Final emotion 'disgust' lasted for 1.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/03-01-46-01.mp4
# processing  03-01-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'disgust'
# Emotion 'disgust' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/03-02-46-01.mp4
# processing  03-02-46-01.mp4
# Starting with emotion 'disgust' at 0.0s
# Emotion 'disgust' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 3.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/04-01-46-01.mp4
# processing  04-01-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 3.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/04-02-46-01.mp4
# processing  04-02-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 1.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/05-01-46-01.mp4
# processing  05-01-46-01.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 0.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/46/05-02-46-01.mp4
# processing  05-02-46-01.mp4
# Starting with emotion 'sad' at 0.0s
# Final emotion 'sad' lasted for 2.8 seconds
# Analysis complete.
# Saved 22 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/46
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/47 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/47/01-01-47-01.mp4
# processing  01-01-47-01.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/01-02-47-01.mp4
# processing  01-02-47-01.mp4
# Starting with emotion 'happy' at 0.0s
# Final emotion 'happy' lasted for 2.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/02-01-47-01.mp4
# processing  02-01-47-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'surprise'
# Final emotion 'surprise' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/02-02-47-01.mp4
# processing  02-02-47-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 0.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/03-01-47-01.mp4
# processing  03-01-47-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'surprise'
# Final emotion 'surprise' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/03-02-47-01.mp4
# processing  03-02-47-01.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/04-01-47-01.mp4
# processing  04-01-47-01.mp4
# Starting with emotion 'happy' at 0.0s
# Final emotion 'happy' lasted for 2.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/04-02-47-01.mp4
# processing  04-02-47-01.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'angry'
# Final emotion 'angry' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/05-01-47-01.mp4
# processing  05-01-47-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.5 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/47/05-02-47-01.mp4
# processing  05-02-47-01.mp4
# Starting with emotion 'angry' at 0.0s
# Emotion 'angry' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.6 seconds
# Analysis complete.
# Saved 26 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/47
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/48 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/48/01-01-48-01.mp4
# processing  01-01-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/01-02-48-01.mp4
# processing  01-02-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'fear'
# Final emotion 'fear' lasted for 0.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/02-01-48-01.mp4
# processing  02-01-48-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Emotion 'neutral' lasted for 2.0 seconds
# At 3.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/02-02-48-01.mp4
# processing  02-02-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 4.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/03-01-48-01.mp4
# processing  03-01-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'angry'
# Emotion 'angry' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'disgust'
# Final emotion 'disgust' lasted for 0.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/03-02-48-01.mp4
# processing  03-02-48-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/04-01-48-01.mp4
# processing  04-01-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Emotion 'sad' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 1.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/04-02-48-01.mp4
# processing  04-02-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'sad'
# Final emotion 'sad' lasted for 3.9 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/05-01-48-01.mp4
# processing  05-01-48-01.mp4
# Starting with emotion 'sad' at 0.0s
# Emotion 'sad' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.3 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/48/05-02-48-01.mp4
# processing  05-02-48-01.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'surprise'
# Final emotion 'surprise' lasted for 0.5 seconds
# Analysis complete.
# Saved 28 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/48
#
# === Folder: /content/drive/MyDrive/Recordings/Recordings/49 ===
# >>> /content/drive/MyDrive/Recordings/Recordings/49/01-01-49-04.mp4
# processing  01-01-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'happy'
# Emotion 'happy' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/01-02-49-04.mp4
# processing  01-02-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 3.0 seconds
# At 3.0s, dominant emotion changed to 'happy'
# Final emotion 'happy' lasted for 0.6 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/02-01-49-04.mp4
# processing  02-01-49-04.mp4
# Starting with emotion 'happy' at 0.0s
# Emotion 'happy' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 3.7 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/02-02-49-04.mp4
# processing  02-02-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/03-01-49-04.mp4
# processing  03-01-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 1.0 seconds
# At 1.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 2.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 2.0 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/03-02-49-04.mp4
# processing  03-02-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 2.8 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/04-01-49-04.mp4
# processing  04-01-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 4.4 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/04-02-49-04.mp4
# processing  04-02-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Emotion 'neutral' lasted for 2.0 seconds
# At 2.0s, dominant emotion changed to 'fear'
# Emotion 'fear' lasted for 1.0 seconds
# At 3.0s, dominant emotion changed to 'neutral'
# Final emotion 'neutral' lasted for 0.2 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/05-01-49-04.mp4
# processing  05-01-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.1 seconds
# Analysis complete.
# >>> /content/drive/MyDrive/Recordings/Recordings/49/05-02-49-04.mp4
# processing  05-02-49-04.mp4
# Starting with emotion 'neutral' at 0.0s
# Final emotion 'neutral' lasted for 3.6 seconds
# Analysis complete.
# Saved 18 new rows from folder: /content/drive/MyDrive/Recordings/Recordings/49
#
# Resume-ready CSV updated: /content/drive/MyDrive/emotion_results.csv
# Total processed folders: 49 | New rows added: 1181 | Total rows in CSV: 1233
