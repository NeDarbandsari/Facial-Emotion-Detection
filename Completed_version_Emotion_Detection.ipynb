# %% [markdown]
# <a href="https://colab.research.google.com/github/NeDarbandsari/Facial-Emotion-Detection/blob/main/Completed_version_Emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import display
# !pip install deepface
display.clear_output()

from deepface import DeepFace
import cv2
import os
from google.colab import drive

import pandas as pd
import json

from itertools import groupby
# Out:
# 25-12-09 14:41:57 - Directory /root/.deepface has been created
# 25-12-09 14:41:57 - Directory /root/.deepface/weights has been created

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)

ZIP_PATH = "/content/drive/MyDrive/Recordings.zip"
ROOT_DIR = "/content/drive/MyDrive/Recordings"
OUTPUT_CSV = "/content/drive/MyDrive/emotion_results.csv"
ALLOWED_EXTS = (".mp4", ".mov", ".avi", ".mkv", ".m4v")


if not os.path.exists(ROOT_DIR):
    print("Extracting dataset, please wait...")
    import zipfile
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(ROOT_DIR)
    print("Extraction complete:", ROOT_DIR)
else:
    print("Dataset folder already exists:", ROOT_DIR)
# Out:
# Mounted at /content/drive
# Dataset folder already exists: /content/drive/MyDrive/Recordings

# %%
def iter_videos(root_dir, allowed_exts=ALLOWED_EXTS):
    for dirpath, dirnames, filenames in os.walk(root_dir):
        dirnames.sort()
        for fn in sorted(filenames):
            if fn.lower().endswith(allowed_exts):
                yield dirpath, fn, os.path.join(dirpath, fn)

all_videos = list(iter_videos(ROOT_DIR))
print(f"Found {len(all_videos)} video(s). Example:", all_videos[0])
# Out:
# Found 1002 video(s). Example: ('/content/drive/MyDrive/Recordings/01', '01-01-01-01.mp4', '/content/drive/MyDrive/Recordings/01/01-01-01-01.mp4')

# %%
def video_emotion_detection(video, backends, alignment_modes, model,video_path):
  emotion_model = DeepFace.build_model(model)
  DeepFace.custom_models = {model: emotion_model}
  print("processing ", video)

  cap = cv2.VideoCapture(os.path.join(video_path, video))

  fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
  frame_interval = int(fps)

  prev_emotion = None
  start_time = None
  frame_count = 0
  result = {}
  result['file'] = video
  result['model'] = model
  result['backends'] = backends

  emotion=[]

  while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

      # Process only every frame_interval-th frame
    if frame_count % frame_interval == 0:
        process = {}
        current_time = frame_count / fps  # current time in seconds
        try:
            # Analyze the current frame for emotion
            analysis = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False, detector_backend = backends)

            # If the result is a list (multiple faces), take the first one
            if isinstance(analysis, list):
                analysis = analysis[0]
            curr_emotion = analysis['dominant_emotion']

            # Initialize on the first processed frame
            if prev_emotion is None:
                prev_emotion = curr_emotion
                start_time = current_time
                print(f"Starting with emotion '{curr_emotion}' at {current_time:.1f}s")
                process['starting emotion'] = curr_emotion
                process['time'] = current_time
            # When the emotion changes, print the duration and update the tracker
            elif curr_emotion != prev_emotion:
                duration = current_time - start_time
                print(f"Emotion '{prev_emotion}' lasted for {duration:.1f} seconds")
                process['prev_emotion'] = prev_emotion
                process['duration'] = duration
                print(f"At {current_time:.1f}s, dominant emotion changed to '{curr_emotion}'")
                process['curr_emotion'] = curr_emotion
                process['current_time'] =current_time
                prev_emotion = curr_emotion
                start_time = current_time
            if len(process) != 0:
              emotion.append(process)
        except Exception as e:
            print(f"Error analyzing frame {frame_count}: {e}")


    frame_count += 1
  cap.release()
  # Print the duration for the final emotion
  total_time = frame_count / fps
  if prev_emotion is not None and start_time is not None:
    final_duration = total_time - start_time
    print(f"Final emotion '{prev_emotion}' lasted for {final_duration:.1f} seconds")
  print("Analysis complete.")
  result['emotions'] = emotion
  return result

# %%
backends = [
  'opencv',
  'ssd',
  'dlib',
  'mtcnn',
  'fastmtcnn',
  'retinaface',
  'mediapipe',
  'yolov8',
  'yolov11s',
  'yolov11n',
  'yolov11m',
  'yunet',
  'centerface',
]

alignment_modes = [True, False]

supported_models = [
    "VGG-Face",
    "Facenet",
    "Facenet512",
    "OpenFace",
    "DeepFace",
    "DeepID",
    "ArcFace",
    "Dlib",
    "SFace",
]

# %%
chosen_backend   = backends[3]          # mtcnn
chosen_alignment = alignment_modes[0]   # True
chosen_model     = supported_models[3]  # OpenFace


def result_to_rows(r):
    """Flatten one video result dict into per-segment CSV rows."""
    base = {
        "folder": r.get("folder"),
        "file":   r.get("file"),
        "path":   r.get("path"),
        "model":  r.get("model"),
        "backend":r.get("backends"),
    }
    rows = []
    for emo in r.get("emotions", []):
        row = base.copy()
        row.update(emo)
        rows.append(row)
    return rows

def append_rows(rows, csv_path):
    """Append rows to CSV safely."""
    if not rows:
        return 0
    df = pd.DataFrame(rows)
    header_needed = (not os.path.exists(csv_path)) or os.stat(csv_path).st_size == 0
    df.to_csv(csv_path, mode="a", header=header_needed, index=False)
    return len(df)


# 1) Load existing CSV and mark already-processed videos
if os.path.exists(OUTPUT_CSV):
    try:
        existing = pd.read_csv(OUTPUT_CSV, usecols=["path"])
        processed_paths = set(existing["path"].astype(str))
        print(f"Found {len(processed_paths)} already processed videos in CSV.")
    except Exception:
        processed_paths = set()
        print("Could not read previous CSV — starting fresh.")
else:
    processed_paths = set()
    print("No existing CSV found. Starting fresh.")


# 2) Group videos by folder and process only new ones
all_videos_sorted = sorted(all_videos, key=lambda t: (t[0], t[1]))
total_appended = 0
folders_done = 0

try:
    for folder_path, group in groupby(all_videos_sorted, key=lambda t: t[0]):
        group = list(group)
        print(f"\n=== Folder: {folder_path} ===")

        # filter only new videos
        new_files = [(p, f, fp) for (p, f, fp) in group if fp not in processed_paths]
        if not new_files:
            print("All videos in this folder already processed.")
            folders_done += 1
            continue

        folder_rows = []
        for _, file_name, file_path in new_files:
            print(">>>", file_path)
            out = video_emotion_detection(
                file_name, chosen_backend, chosen_alignment, chosen_model, folder_path + os.sep
            )
            out["folder"] = folder_path
            out["path"] = file_path
            folder_rows.extend(result_to_rows(out))
            processed_paths.add(file_path)  # mark done in memory

        added = append_rows(folder_rows, OUTPUT_CSV)
        total_appended += added

        print(f"Saved {added} new rows from folder: {folder_path}")
        folders_done += 1

        try:
            peek = pd.read_csv(OUTPUT_CSV).tail(3)
            display(peek)
        except Exception:
            pass

except KeyboardInterrupt:
    print("\nStopped manually — progress saved so far.")

finally:
    if os.path.exists(OUTPUT_CSV):
        total_rows = pd.read_csv(OUTPUT_CSV).shape[0]
        print(f"\nResume-ready CSV updated: {OUTPUT_CSV}")
        print(f"Total processed folders: {folders_done} | New rows added: {total_appended} | Total rows in CSV: {total_rows}")
    else:
        print("\nNo CSV file was written yet.")
# Out:
# Found 1002 already processed videos in CSV.
#
# === Folder: /content/drive/MyDrive/Recordings/01 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/02 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/03 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/04 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/05 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/06 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/07 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/08 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/09 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/10 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/100 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/11 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/12 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/13 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/14 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/15 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/16 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/17 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/18 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/19 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/20 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/21 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/22 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/23 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/24 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/25 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/26 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/27 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/28 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/29 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/30 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/31 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/32 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/33 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/34 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/35 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/36 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/37 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/38 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/39 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/40 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/41 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/42 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/43 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/44 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/45 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/46 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/47 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/48 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/49 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/50 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/51 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/52 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/53 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/54 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/55 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/56 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/57 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/58 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/59 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/60 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/61 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/62 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/63 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/64 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/65 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/66 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/67 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/68 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/69 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/70 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/71 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/72 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/73 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/74 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/75 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/76 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/77 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/78 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/79 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/80 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/81 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/82 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/83 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/84 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/85 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/86 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/87 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/88 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/89 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/90 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/91 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/92 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/93 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/94 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/95 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/96 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/97 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/98 ===
# All videos in this folder already processed.
#
# === Folder: /content/drive/MyDrive/Recordings/99 ===
# All videos in this folder already processed.
#
# Resume-ready CSV updated: /content/drive/MyDrive/emotion_results.csv
# Total processed folders: 100 | New rows added: 0 | Total rows in CSV: 2386

# %%
# A separate CSV for evaluating multiple backend/model combinations
OUTPUT_CSV_COMBOS = "/content/drive/MyDrive/emotion_results_combos.csv"

# Best combinations for facial emotion recognition
BEST_COMBINATIONS = [
    ("retinaface", "Facenet512"),
    ("retinaface", "ArcFace"),

    ("mtcnn", "Facenet512"),
   # ("mtcnn", "OpenFace"),

   # ("mediapipe", "Facenet512"),
]

# %%
import os
import pandas as pd

print("Running backend/model combination evaluation (safe resume)...")

# Load already-processed combos from CSV
if os.path.exists(OUTPUT_CSV_COMBOS):
    prev_df = pd.read_csv(OUTPUT_CSV_COMBOS)

    if {"path", "backend", "model"}.issubset(prev_df.columns):
        processed_combos = set(
            zip(
                prev_df["path"].astype(str),
                prev_df["backend"].astype(str),
                prev_df["model"].astype(str),
            )
        )
        print(f"Loaded {len(prev_df)} existing rows from {OUTPUT_CSV_COMBOS}")
        print(f"{len(processed_combos)} unique (path, backend, model) combos already processed.")
    else:
        processed_combos = set()
        print(f"{OUTPUT_CSV_COMBOS} exists but is missing required columns; starting fresh.")
else:
    processed_combos = set()
    print(f"No existing {OUTPUT_CSV_COMBOS} found. Starting fresh.")

# Safe / resumable combo loop
total_appended_combos = 0
folders_done = 0

for root, dirs, files in os.walk(ROOT_DIR):
    video_files = [f for f in files if f.lower().endswith(ALLOWED_EXTS)]
    if not video_files:
        continue

    print(f"\n Folder: {root}")

    # rows for this folder only
    folder_rows_combos = []

    try:
        for file_name in video_files:
            file_path = os.path.join(root, file_name)
            print(f"Processing: {file_path}")

            for backend_name, model_name in BEST_COMBINATIONS:
                combo_key = (file_path, backend_name, model_name)

                # skip if this combo has already been written before
                if combo_key in processed_combos:
                    # Debugging:
                    # print(f"Already done: {combo_key}")
                    continue

                print(f"   → Combo: backend={backend_name}, model={model_name}")

                try:
                    # match existing function signature: positional args
                    out_combo = video_emotion_detection(
                        file_name,        # video file name
                        backend_name,     # detector backend
                        chosen_alignment, # alignment
                        model_name,       # model
                        root + os.sep     # folder path
                    )
                except Exception as e:

                    print(f"Skipping {combo_key} due to error: {e}")
                    # do NOT add to processed_combos fix & retry later
                    continue

                # add metadata
                out_combo["folder"] = root
                out_combo["path"] = file_path
                out_combo["backend"] = backend_name
                out_combo["model"] = model_name

                # convert to CSV rows
                rows = result_to_rows(out_combo)
                folder_rows_combos.extend(rows)

                # mark as processed in-memory so this run doesn't repeat it
                processed_combos.add(combo_key)

    except KeyboardInterrupt:
        # if manually stop in the middle of this folder, still save what we have
        if folder_rows_combos:
            added = append_rows(folder_rows_combos, OUTPUT_CSV_COMBOS)
            total_appended_combos += added
            print(f"\n⏸ KeyboardInterrupt – saved {added} rows from folder: {root} before stopping.")
        raise  # re-raise so the interrupt behaves normally

    # normal per-folder save
    if folder_rows_combos:
        added = append_rows(folder_rows_combos, OUTPUT_CSV_COMBOS)
        total_appended_combos += added
        print(f"   Saved {added} new rows from folder: {root}")

    folders_done += 1

print(f"\Finished combo evaluation.")
print(f"Total new rows added in this run: {total_appended_combos}")
print(f"Folders visited: {folders_done}")
# Out:
# Running backend/model combination evaluation (safe resume)...
# Loaded 6858 existing rows from /content/drive/MyDrive/emotion_results_combos.csv
# 3006 unique (path, backend, model) combos already processed.
#
#  Folder: /content/drive/MyDrive/Recordings/25
# Processing: /content/drive/MyDrive/Recordings/25/03-01-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/02-02-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/01-02-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/04-01-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/03-02-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/02-01-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/01-01-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/04-02-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/05-01-25-01.mp4
# Processing: /content/drive/MyDrive/Recordings/25/05-02-25-01.mp4
#
#  Folder: /content/drive/MyDrive/Recordings/22
# Processing: /content/drive/MyDrive/Recordings/22/03-01-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/05-01-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/02-02-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/05-02-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/04-02-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/01-01-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/01-02-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/02-01-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/03-02-22-03.mp4
# Processing: /content/drive/MyDrive/Recordings/22/04-01-22-03.mp4
#
#  Folder: /content/drive/MyDrive/Recordings
mp4
#
#  Folder: /content/drive/MyDrive/Recordings/61
# Processing: /content/drive/MyDrive/Recordings/61/01-01-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/01-02-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/02-01-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/05-01-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/03-01-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/04-02-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/04-01-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/05-02-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/02-02-61-02.mp4
# Processing: /content/drive/MyDrive/Recordings/61/03-02-61-02.mp4
#
#  Folder: /content/drive/MyDrive/Recordings/92
# Processing: /content/drive/MyDrive/Recordings/92/01-02-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/04-01-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/02-01-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/05-02-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/02-02-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/01-01-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/04-02-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/03-02-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/03-01-92-02.mp4
# Processing: /content/drive/MyDrive/Recordings/92/05-01-92-02.mp4
#
#  Folder: /content/drive/MyDrive/Recordings/66
# Processing: /content/drive/MyDrive/Recordings/66/02-02-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/04-02-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/03-02-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/05-01-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/02-01-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/01-02-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/03-01-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/05-02-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/04-01-66-02.mp4
# Processing: /content/drive/MyDrive/Recordings/66/01-01-66-02.mp4
#
#  Folder: /content/drive/MyDrive/Recordings/03
# Processing: /content/drive/MyDrive/Recordings/03/02-02-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/01-02-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/04-01-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/05-02-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/01-01-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/03-01-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/04-02-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/05-01-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/02-01-03-02.mp4
# Processing: /content/drive/MyDrive/Recordings/03/03-02-03-02.mp4
# \Finished combo evaluation.
# Total new rows added in this run: 0
# Folders visited: 100
